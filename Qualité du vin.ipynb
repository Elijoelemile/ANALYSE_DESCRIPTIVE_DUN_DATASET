# %% [markdown]
# # Importer les dépendances

# %%
import pandas as pd  #manipulation des donnees
import numpy as np   #calcul mathematiques
import seaborn as sns   #visualiser les données
import matplotlib.pyplot as plt  #visualisation
import scipy as scipy   # faire des statistques et des probabilités
import warnings         #gestion des avertissements
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importer les données

# %%
data=pd.read_csv('Analyser la qualité du vin.csv', sep=';')
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
# Voir les données sur 60 lignes
data.head(60)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.0              0.27         0.36           20.70      0.045
# 1             6.3              0.30         0.34            1.60      0.049
# 2             8.1              0.28         0.40            6.90      0.050
# 3             7.2              0.23         0.32            8.50      0.058
# 4             7.2              0.23         0.32            8.50      0.058
# 5             8.1              0.28         0.40            6.90      0.050
# 6             6.2              0.32         0.16            7.00      0.045
# 7             7.0              0.27         0.36           20.70      0.045
# 8             6.3              0.30         0.34            1.60      0.049
# 9             8.1              0.22         0.43            1.50      0.044
# 10            8.1              0.27         0.41            1.45      0.033
# ...

# %% [markdown]
# # Exploration de données
#
# ## <font color="black">Les questions qu'on pourrait se poser pour l'exploration de données sont:</font>
# ##### 1- Quels sont les noms des variables de mon DataFrame?
# <font color="red">'fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality'.</font>
# ##### 2- Quels types de données possède mon DataFrame?
# <font color="red">Données Numériques.</font>
# ##### 3- Combien de lignes et colonnes possède mon DataFrame?
# <font color="red">4898 lignes et 12 colonnes.</font>
# ##### 4- Combien de données totales possède mon DataFrame?
# <font color="red">58776 Données.</font>
# ##### 5- Si je ferai du Machine Learning,la variable à prédire est-elle qualitative: ordinale ou nominale? Ou est-elle quantitative: continue ou discrète? Ici ‘quality’  à prédire.
# <font color="red">La variable 'quality' est une variable discrète.</font>
# ##### 6- Mon DataFrame possède-t-il des données Manquantes?
# <font color="red">Aucune Donnée manquante.</font>
# ##### 7- Mon DataFrame possède-t-il des données Dupliquées?
# <font color="red">937 Données Dupliquées.</font>
# ##### 8- Mon DataFrame possède-t-il des données Aberrantes?
# <font color="red">On remarque sur notre graphique la présence de Données Aberrantes voir même Extrêmes.</font>

# %%
#Vérifions les noms des variables
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# Les types de données que possède notre DataFrame

data.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
# Nombres de lignes et de colonnes 

data.shape
# Out:
# (4898, 12)

# %%
# Nombre total de données du DataFrame

nbrdonnee=4898*12
nbrdonnee
# Out:
# 58776

# %%
# Nombre de données manquantes

data.isna().sum().sum()
# Out:
# 0

# %%
# Nombre de données dupliquées

data.duplicated().sum()
# Out:
# 937

# %%
# Quelle est la variable à prédire?

'quality'
# Out:
# 'quality'

# %%
# Savoir si la variable à prédire est continue ou discrète

data['quality'].unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9], dtype=int64)

# %%
# Savoir si nous avons la présence de données aberrantes

plt.figure(figsize=(15,5))
sns.boxplot(data=data, palette='bright')
plt.show()
